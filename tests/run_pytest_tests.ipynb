# %% [markdown]
# ### Run Unit Test Cases

# %%
# Base path in your workspace
USER_EMAIL = spark.sql("SELECT current_user()").collect()[0][0]
TEST_PATH = f"/Workspace/Users/{USER_EMAIL}/retail-cdc-lakehouse/tests/test_etl_pipeline.py"

# %%
# !pytest "$TEST_PATH" -v
